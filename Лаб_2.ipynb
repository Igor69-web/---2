# %% [markdown]
# <a href="https://colab.research.google.com/github/Igor69-web/---2/blob/main/%D0%9B%D0%B0%D0%B1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# График 2.1.2

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("График массива x = [1,2,3,4,6], y = [2,4,1,3,2] ") # заголовок
plt.xlabel("Ось x") # ось абсцисс
plt.ylabel("Ось y") # ось ординат
plt.plot([1,2,3,4,6], [2,4,1,3,2])  # построение графика

# %% [markdown]
# График 2.2.2

# %%
import numpy as np
import matplotlib.pyplot as plt
x = ('Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C ++')
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
x_pos = [i for i, _ in enumerate(x)]
plt.barh (x_pos,popularity , color = 'green')
plt.xlabel("Popularity")
plt.ylabel("Languages")
plt.title("PopularitY of Programming Language\n" + "Worldwide, Oct 2017 compared to a year ago")
plt.yticks(x_pos, x)
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %% [markdown]
# График 2.3.2

# %%
import numpy as np
import matplotlib.pyplot as plt
labels = ('Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C ++')
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
fig = plt.figure(figsize = (6,4))
ax = fig.add_subplot()
ax.pie(popularity,labels = labels,autopct='%1.1f%%')
ax.grid()
plt.show()

# %% [markdown]
# График 2.4.2

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.randn(40)
y = np.random.randn(40)
plt.scatter(x,y,s=40,facecolors = 'none',edgecolors = 'g')
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# !mkdir ~/.kaggle

# %%
# !ls

# %%
# !echo '{"username":"butsigor","key":"2520055e9d721ca52ba5119c26101028"}'> ~/.kaggle/kaggle.json

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install kaggle

# %%
# !kaggle datasets list -s 'course'
# Out:
# ref                                                              title                                                 size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------------  --------------------------------------------------  ------  -------------------  -------------  ---------  ---------------
# datasets/siddharthm1698/coursera-course-dataset                  Coursera Course Dataset                               23KB  2020-05-25 05:52:27           4701        157  1.0
# datasets/jilkothari/finance-accounting-courses-udemy-13k-course  Finance & Accounting Courses - Udemy (13K+ course)  1000KB  2020-09-17 12:46:12           4295        112  1.0
# datasets/kashnitsky/mlcourse                                     mlcourse.ai                                           51MB  2018-12-09 16:45:09          30381       1424  0.88235295
# ...

# %%
# !kaggle datasets download -d siddharthm1698/coursera-course-dataset
# Out:
# ...
#   0% 0.00/22.8k [00:00<?, ?B/s]
# 100% 22.8k/22.8k [00:00<00:00, 12.9MB/s]

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# coursera-course-dataset.zip  sample_data

# %%
# !pip install patool
import patoolib
# Out:
# ...
#      |████████████████████████████████| 77 kB 3.2 MB/s
# ...

# %%
patoolib.extract_archive('coursera-course-dataset.zip',outdir = 'kaggle')
# Out:
# patool: Extracting coursera-course-dataset.zip ...
# patool: running /usr/bin/7z x -okaggle -- coursera-course-dataset.zip
# patool: ... coursera-course-dataset.zip extracted to `kaggle'.
# 'kaggle'

# %%
# !ls kaggle
# Out:
# coursea_data.csv

# %%
# !ls
# Out:
# coursera-course-dataset.zip  kaggle  sample_data

# %%
df2 = pd.read_csv('kaggle/coursea_data.csv',sep=',',parse_dates=True,index_col=0)
df2
# Out:
#                                           course_title  \
# 134  (ISC)² Systems Security Certified Practitioner...
# 743  A Crash Course in Causality:  Inferring Causal...
# 874                     A Crash Course in Data Science
# 413                            A Law Student's Toolkit
# 635                A Life of Happiness and Fulfillment
# ..                                                 ...
# 236                         Программирование на Python
# 883               Психолингвистика (Psycholinguistics)
# 545       Разработка интерфейсов: вёрстка и JavaScript
# 875                            Русский как иностранный
# 163      Финансовые инструменты для частного инвестора
#
#                                    course_organization  \
# 134                                             (ISC)²
# 743                         University of Pennsylvania
# 874                           Johns Hopkins University
# 413                                    Yale University
# ...

# %%
df3 = df2[['course_title','course_rating']]
title = df2['course_title']
raiting = df2['course_rating']
diag = df3.head()
diag
# Out:
#                                           course_title  course_rating
# 134  (ISC)² Systems Security Certified Practitioner...            4.7
# 743  A Crash Course in Causality:  Inferring Causal...            4.7
# 874                     A Crash Course in Data Science            4.5
# 413                            A Law Student's Toolkit            4.7
# 635                A Life of Happiness and Fulfillment            4.8

# %%
diag.plot(x='course_title', y='course_rating', kind='barh')
